# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline
sns.set_style('whitegrid')

# %% [markdown]
# ## Carga de Datos

# %%
# TODO: Cargar el dataset de churn
# df = pd.read_csv('ruta/al/dataset.csv')
# df.head()

# %% [markdown]
# ## Análisis Exploratorio

# %%
# TODO: Análisis de distribución de variables
# df.describe()
# df.info()
